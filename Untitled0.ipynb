# %% [markdown]
# <a href="https://colab.research.google.com/github/rvigneshwaran20078/ML-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Import Libraries

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# 2.Load Dataset

# %%
df = pd.read_csv("/retail_sales_dataset (1).csv")

# %% [markdown]
# 3.Delete Unwanted colums

# %%
df = df.drop(["Transaction ID", "Customer ID", "Date"], axis=1)

# %% [markdown]
#  4. Convert categorical columns to numbers

# %%
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# 5.Scale the data

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %% [markdown]
# 6. Apply K-Means

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df["Cluster"] = kmeans.fit_predict(scaled_data)

# %%
print(df.to_string())
# Out:
#      Age  Quantity  Price per Unit  Total Amount  Gender_Male  Product Category_Clothing  Product Category_Electronics  Cluster
# 0     34         3              50           150         True                      False                         False        2
# 1     26         2             500          1000        False                       True                         False        1
# 2     50         1              30            30         True                      False                          True        0
# 3     37         1             500           500         True                       True                         False        1
# 4     30         2              50           100         True                      False                         False        0
# 5     45         1              30            30        False                      False                         False        0
# ...
